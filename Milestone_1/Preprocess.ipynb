# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Dataset

df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/FitPulse_data.csv')
df.head()
# Out:
#             time_stamp  heart_rate  step_count sleep_tracking Patient_ID  \
# 0  2025-01-14 16:50:00   74.499653        26.0          awake      P0001
# 1  2025-01-21 08:55:00   90.833116         6.0          awake      P0002
# 2  2025-01-17 07:10:00   61.270774        40.0          awake      P0003
# 3  2025-01-28 08:55:00         NaN        38.0          awake      P0004
# 4  2025-01-18 18:25:00   59.807869        29.0       exercise      P0005
#
#    Weight  Height
# 0      88     168
# 1      78     162
# 2      64     162
# 3      57     177
# 4      70     151

# %%
df.shape
# Out:
# (8671, 7)

# %%
# To find statistical values(min, max, mean, count,std)
df.describe()
# Out:
#         heart_rate   step_count       Weight       Height
# count  8262.000000  8334.000000  8671.000000  8671.000000
# mean     72.326340    26.309935    69.615039   169.302272
# std      12.002177    54.358931    11.482452    11.416578
# min      32.776138     0.000000    50.000000   150.000000
# 25%      65.378882    12.000000    60.000000   159.000000
# 50%      72.194583    25.000000    70.000000   169.000000
# 75%      78.885036    37.000000    79.000000   179.000000
# max     248.000000  1909.000000    89.000000   189.000000

# %%
# To find data types of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8671 entries, 0 to 8670
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   time_stamp      8671 non-null   object
#  1   heart_rate      8262 non-null   float64
#  2   step_count      8334 non-null   float64
#  3   sleep_tracking  8671 non-null   object
#  4   Patient_ID      8671 non-null   object
#  5   Weight          8671 non-null   int64
#  6   Height          8671 non-null   int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 474.3+ KB

# %%
# To find null values
df.isnull().sum()
# Out:
# time_stamp          0
# heart_rate        409
# step_count        337
# sleep_tracking      0
# Patient_ID          0
# Weight              0
# Height              0
# dtype: int64

# %%
# To find percentage of null values
df.isnull().mean()*100
# Out:
# time_stamp        0.000000
# heart_rate        4.716872
# step_count        3.886518
# sleep_tracking    0.000000
# Patient_ID        0.000000
# Weight            0.000000
# Height            0.000000
# dtype: float64

# %%
# Convert timestamp
df['time_stamp'] = pd.to_datetime(df['time_stamp'], errors='coerce')

# %%
df.head()
# Out:
#            time_stamp  heart_rate  step_count sleep_tracking Patient_ID  \
# 0 2025-01-14 16:50:00   74.499653        26.0          awake      P0001
# 1 2025-01-21 08:55:00   90.833116         6.0          awake      P0002
# 2 2025-01-17 07:10:00   61.270774        40.0          awake      P0003
# 3 2025-01-28 08:55:00         NaN        38.0          awake      P0004
# 4 2025-01-18 18:25:00   59.807869        29.0       exercise      P0005
#
#    Weight  Height
# 0      88     168
# 1      78     162
# 2      64     162
# 3      57     177
# 4      70     151

# %%
# Removing missing values
print(f"Shape of DataFrame before removing missing values: {df.shape}")
df = df.dropna()
# Out:
# Shape of DataFrame before removing missing values: (8671, 7)

# %%
print(f"Shape of DataFrame after removing missing values: {df.shape}")
display(df.head())
# Out:
# Shape of DataFrame after removing missing values: (7936, 7)
#            time_stamp  heart_rate  step_count sleep_tracking Patient_ID  \
# 0 2025-01-14 16:50:00   74.499653        26.0          awake      P0001
# 1 2025-01-21 08:55:00   90.833116         6.0          awake      P0002
# 2 2025-01-17 07:10:00   61.270774        40.0          awake      P0003
# 4 2025-01-18 18:25:00   59.807869        29.0       exercise      P0005
# 5 2025-01-13 07:20:00   92.702179        34.0          awake      P0006
#
#    Weight  Height
# 0      88     168
# 1      78     162
# 2      64     162
# 4      70     151
# 5      88     159

# %%
print(f"Shape of DataFrame before removing duplicate values: {df.shape}")
df = df.drop_duplicates()
# Out:
# Shape of DataFrame before removing duplicate values: (7936, 7)

# %%
print(f"Shape of DataFrame after removing duplicate values: {df.shape}")
display(df.head())
# Out:
# Shape of DataFrame after removing duplicate values: (7936, 7)
#            time_stamp  heart_rate  step_count sleep_tracking Patient_ID  \
# 0 2025-01-14 16:50:00   74.499653        26.0          awake      P0001
# 1 2025-01-21 08:55:00   90.833116         6.0          awake      P0002
# 2 2025-01-17 07:10:00   61.270774        40.0          awake      P0003
# 4 2025-01-18 18:25:00   59.807869        29.0       exercise      P0005
# 5 2025-01-13 07:20:00   92.702179        34.0          awake      P0006
#
#    Weight  Height
# 0      88     168
# 1      78     162
# 2      64     162
# 4      70     151
# 5      88     159

# %%
df.head()
# Out:
#            time_stamp  heart_rate  step_count sleep_tracking Patient_ID  \
# 0 2025-01-14 16:50:00   74.499653        26.0          awake      P0001
# 1 2025-01-21 08:55:00   90.833116         6.0          awake      P0002
# 2 2025-01-17 07:10:00   61.270774        40.0          awake      P0003
# 4 2025-01-18 18:25:00   59.807869        29.0       exercise      P0005
# 5 2025-01-13 07:20:00   92.702179        34.0          awake      P0006
#
#    Weight  Height
# 0      88     168
# 1      78     162
# 2      64     162
# 4      70     151
# 5      88     159

# %%
df.describe()
# Out:
#                           time_stamp   heart_rate   step_count       Weight  \
# count                           7936  7936.000000  7936.000000  7936.000000
# mean   2025-01-16 03:28:18.613911296    72.328827    26.358997    69.635585
# min              2025-01-01 00:00:00    32.776138     0.000000    50.000000
# 25%              2025-01-08 13:13:45    65.382890    12.000000    60.000000
# 50%              2025-01-16 00:42:30    72.193312    25.000000    70.000000
# 75%              2025-01-23 12:51:15    78.862154    37.000000    79.000000
# max              2025-12-01 00:10:00   248.000000  1909.000000    89.000000
# std                              NaN    12.074800    55.608081    11.457261
#
#             Height
# count  7936.000000
# mean    169.335433
# min     150.000000
# 25%     159.000000
# 50%     169.000000
# 75%     179.000000
# max     189.000000
# std      11.415988

# %%
# Distribution Plots
plt.figure()
sns.histplot(df['heart_rate'], kde=True)
plt.title("Heart Rate Distribution")
plt.show()

plt.figure()
sns.histplot(df['step_count'], kde=True)
plt.title("Step Count Distribution")
plt.show()

plt.figure()
sns.countplot(x='sleep_tracking', data=df)
plt.title("Sleep Count Distribution")
plt.show()

# %%
# Outlier Detection of heart_rate
Q1 = df['heart_rate'].quantile(0.25)
Q3 = df['heart_rate'].quantile(0.75)
IQR = Q3 - Q1

outliers = df[(df['heart_rate'] < Q1 - 1.5*IQR) |
              (df['heart_rate'] > Q3 + 1.5*IQR)]

print("Number of heart rate outliers:", outliers.shape[0])
# Out:
# Number of heart rate outliers: 67

# %%
# Outlier Detection of step_count
Q1 = df['step_count'].quantile(0.25)
Q3 = df['step_count'].quantile(0.75)
IQR = Q3 - Q1

outliers = df[(df['step_count'] < Q1 - 1.5*IQR) |
              (df['step_count'] > Q3 + 1.5*IQR)]

print("Number of heart rate outliers:", outliers.shape[0])
# Out:
# Number of heart rate outliers: 10

# %%
# Removing outliers by deciding range of data

# Heart rate realistic range
df = df[(df['heart_rate'] >= 40) & (df['heart_rate'] <= 200)]

# Step count realistic limit per 5 minutes
df = df[(df['step_count'] >= 0) & (df['step_count'] <= 1500)]

# %%
# Outlier Detection of heart_rate after filtering
Q1 = df['heart_rate'].quantile(0.25)
Q3 = df['heart_rate'].quantile(0.75)
IQR = Q3 - Q1

outliers = df[(df['heart_rate'] < Q1 - 1.5*IQR) |
              (df['heart_rate'] > Q3 + 1.5*IQR)]

print("Number of heart rate outliers:", outliers.shape[0])
# Out:
# Number of heart rate outliers: 45

# %%
# Outlier Detection of step_count after filtering
Q1 = df['step_count'].quantile(0.25)
Q3 = df['step_count'].quantile(0.75)
IQR = Q3 - Q1

outliers = df[(df['step_count'] < Q1 - 1.5*IQR) |
              (df['step_count'] > Q3 + 1.5*IQR)]

print("Number of heart rate outliers:", outliers.shape[0])
# Out:
# Number of heart rate outliers: 5

# %%
df.head()
# Out:
#            time_stamp  heart_rate  step_count sleep_tracking Patient_ID  \
# 0 2025-01-14 16:50:00   74.499653        26.0          awake      P0001
# 1 2025-01-21 08:55:00   90.833116         6.0          awake      P0002
# 2 2025-01-17 07:10:00   61.270774        40.0          awake      P0003
# 4 2025-01-18 18:25:00   59.807869        29.0       exercise      P0005
# 5 2025-01-13 07:20:00   92.702179        34.0          awake      P0006
#
#    Weight  Height
# 0      88     168
# 1      78     162
# 2      64     162
# 4      70     151
# 5      88     159

# %%
df.to_csv("FitPulse_wearable_device_data.csv", index=False)

# %%
from google.colab import files
files.download("FitPulse_wearable_device_data.csv")
